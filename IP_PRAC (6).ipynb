# %%
import time
import pandas as pd
import mysql.connector as c
import datetime
from IPython.display import clear_output
from IPython.display import display

db=c.connect(user='root',
             password='saber_blaze123',
             host='localhost',
             database='default',
             auth_plugin='mysql_native_password')
cursor=db.cursor()
query='select * from student'
cursor.execute(query)
results=cursor.fetchall()
df=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
df.set_index('Scho_no',inplace=True)

def cls():
    clear_output()  
    
def disp():    
    db=c.connect(user='root',
                 password='saber_blaze123',
                 host='localhost',
                 database='default',
                 auth_plugin='mysql_native_password')    
    cursor=db.cursor()
    query='select * from student order by scholar_no'
    cursor.execute(query)
    results=cursor.fetchall()    
    df=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
    df.set_index('Scho_no',inplace=True)
    dis=0
    while dis==0:
        display(df)
        print()
        dis=input('enter any value to go back to main screen:')
        if len(dis)>0:
            dis=1
            cls()
            print()
        else:
            cls()
            dis=0
            
    
def new():
    ent=0
    cursor=db.cursor()
    sc=input('Enter scholar no: ')
    sc=sc.strip()
    if sc.isdigit():
        if sc in df.index:
            cls()
            print('''Scholar no already exists 
            could not enter data successfully...
            ''')
        else:
            ent+=1
            print()
            nm=input('Enter name: ')
            nm=nm.title()
            nm=nm.strip()
            if len(nm)==0:
                cls()
                print('''Name field can not be empty
                try again''')
                print()
                print('''redirecting to home screen...
please wait...''')
                time.sleep(0.5)
            else:
                ent+=1
                valid=False
                while valid==False:
                    print()
                    print('''ENTER YOUR BIRTHDAY DETAILS
                    ''')
                    year=input('enter birthday year: ')
                    year=year.strip()
                    if len(year)>=4 and len(year)!=0:

                        if year.isdigit():
                            year=int(year)
                            print()
                            month=input('enter birthday month: ')
                            month=month.strip()
                            if len(month)<=2 and len(month)!=0:
                                if month.isdigit():
                                    month=int(month)
                                    if month>=1 and month<=12:
                                        print()
                                        date=input('enter birthday date: ')
                                        date=date.strip()
                                        if len(date)<=2 and len(date)!=0:
                                            if date.isdigit():
                                                date=int(date)
                                                if date>0 and date<=31:
                                                    if year%4==0 and month == 2 and date>29:
                                                        cls()
                                                        print('date for feb in leap year cant be greater than 29')
                                                        print('try again')
                                                        print()
                                                        time.sleep(2)
                                                    elif year%4!=0 and month == 2 and date>28:
                                                        cls()
                                                        print('date for feb in non leap year cant be greater than 28')
                                                        print('try again')
                                                        print()
                                                        time.sleep(2)
                                                    else:
                                                        dob=datetime.date(year,month,date)
                                                        valid=True
                                                        ent+=1
                                                else:
                                                    cls()
                                                    print('date not valid')
                                                    print('try again')
                                                    print()
                                                    time.sleep(2)
                                            else:
                                                cls()
                                                print('date not digit')
                                                print('try again')
                                                print()
                                                time.sleep(2)
                                        else:
                                            cls()
                                            print('date not valid')
                                            print('try again')
                                            print()
                                            time.sleep(2)
                                    else:
                                        cls()
                                        print('month must be between 1 and 12')
                                        print('try again')
                                        print()
                                        time.sleep(2)
                                else:
                                    cls()
                                    print('mony not digit')
                                    print('try again')
                                    print()
                                    time.sleep(2)
                            else:
                                cls()
                                print('month not valid')
                                print('try again')
                                print()
                                time.sleep(2)

                        else:
                            cls()
                            print('year not digit')
                            print('try again')
                            print()
                            time.sleep(2)
                    else:
                        cls()
                        print('year not valid')
                        print('try again')
                        print()
                        time.sleep(2)
                cla=input('Enter class: ')
                cla=cla.strip()
                if cla.isdigit():
                    cla=int(cla)
                    if cla>=1 and cla<=12:
                        ent+=1
                        sec=input('Enter section: ')
                        sec=sec.strip()
                        sec=sec.title()
                        sect=['A','B','C','D','E','F','G','H','I','J']
                        if sec in sect:
                            ent+=1

                            phy=input('Enter Physics marks: ')
                            phy=phy.strip()
                            PHY=phy.isdigit()
                            if PHY==True:
                                phy=int(phy)
                            while PHY==False:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                PLEASE TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                phy=input('Enter Physics marks: ')
                                phy=phy.strip()
                                PHY=phy.isdigit()
                            phy=int(phy)
                            while phy<0 or phy>100 and PHY==True:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                phy=input('Enter Physics marks: ')
                                phy=phy.strip()
                                PHY=phy.isdigit()
                                while PHY==False:
                                    cls()
                                    print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                    TRY AGAIN...
                                    ''')
                                    time.sleep(2)
                                    cls()
                                    phy=input('Enter Physics marks: ')
                                    PHY=phy.isdigit()

                                if PHY==True:
                                    phy=int(phy)

                            ent+=1
                            math=input('Enter Maths marks: ')
                            math=math.strip()
                            MATH=math.isdigit()
                            if MATH==True:
                                    math=int(math)
                            while MATH==False:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                PLEASE TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                math=input('Enter Math marks: ')
                                math=math.strip()
                                MATH=math.isdigit()
                            math=int(math)
                            while math<0 or math>100 and MATH==True:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                math=input('Enter Math marks: ')
                                math=math.strip()
                                MATH=math.isdigit()
                                while MATH==False:
                                    print("MUST BE AN INTEGER BETWEEN 0 AND 100")
                                    time.sleep(2)
                                    cls()
                                    math=input('Enter math marks: ')
                                    MATH=math.isdigit()
                                if MATH==True:
                                    math=int(math)
                            ent+=1
                            chem=input('Enter Chem marks: ')
                            chem=chem.strip()
                            CHEM=chem.isdigit()
                            if CHEM==True:
                                    chem=int(chem)
                            while CHEM==False:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                chem=input('Enter Chem marks: ')
                                chem=chem.strip()
                                CHEM=chem.isdigit()
                            chem=int(chem)
                            while chem<0 or chem>100 and CHEM==True:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                chem=input('Enter Chem marks: ')
                                chem=chem.strip()
                                CHEM=chem.isdigit()
                                while CHEM==False:
                                    cls()
                                    print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                    TRY AGAIN...
                                    ''')
                                    time.sleep(2)
                                    cls()
                                    chem=input('Enter chemistry marks: ')
                                    CHEM=chem.isdigit()
                                if CHEM==True:
                                    chem=int(chem)
                            ent+=1
                            pe=input('Enter PE marks: ')
                            pe=pe.strip()
                            PE=pe.isdigit()
                            if PE==True:
                                    pe=int(pe)
                            while PE==False:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                pe=input('Enter PE marks: ')
                                pe=pe.strip()
                                PE=pe.isdigit()
                            pe=int(pe)
                            while pe<0 or pe>100 and PE==True:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                pe=input('Enter PE marks: ')
                                pe=pe.strip()
                                PE=pe.isdigit()
                                while PE==False:
                                    print("MUST BE AN INTEGER BETWEEN 0 AND 100")
                                    time.sleep(2)
                                    cls()
                                    pe=input('Enter math marks: ')
                                    PE=pe.isdigit()
                                if PE==True:
                                    pe=int(pe)
                            ent+=1
                            ip=input('Enter IP marks: ')
                            ip=ip.strip()
                            IP=ip.isdigit()
                            if IP==True:
                                    ip=int(ip)
                            while IP==False:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                ip=input('Enter IP marks: ')
                                ip=ip.strip()
                                IP=ip.isdigit()
                            ip=int(ip)
                            while ip<0 or ip>100 and IP==True:
                                cls()
                                print('''MUST BE AN INTEGER BETWEEN 0 AND 100
                                TRY AGAIN...
                                ''')
                                time.sleep(2)
                                cls()
                                ip=input('Enter IP marks: ')
                                ip=ip.strip()
                                IP=ip.isdigit()
                                while IP==False:
                                    print("MUST BE AN INTEGER BETWEEN 0 AND 100")
                                    time.sleep(2)
                                    cls()
                                    ip=input('Enter math marks: ')
                                    IP=ip.isdigit()
                                if IP==True:
                                    ip=int(ip)
                            ent+=1
                            valid=False
                            while valid==False:
                                print('''ENTER YOUR ADDMISSSION DETAILS
                                ''')
                                year=input('enter addmission year: ') 
                                year=year.strip()
                                if len(year)<=4 and len(year)!=0:

                                    if year.isdigit():
                                        year=int(year)
                                        month=input('enter addmission month: ')
                                        month=month.strip()
                                        if len(month)<=2 and len(month)!=0:
                                            if month.isdigit():
                                                month=int(month)
                                                if month>=1 and month<=12:
                                                    date=input('enter addmission date: ')
                                                    date=date.strip()
                                                    if len(date)<=2 and len(date)!=0:
                                                        if date.isdigit():
                                                            date=int(date)
                                                            if date>0 and date<=31:
                                                                if year%4==0 and month == 2 and date>29:
                                                                    cls()
                                                                    print('date for feb in leap yr cant be greater than 29')
                                                                    print('try again')
                                                                    print()
                                                                    time.sleep(2)
                                
                                                                elif year%4!=0 and month == 2 and date>28:
                                                                    cls()
                                                                    print('date for feb cant be greater than 28')
                                                                    print('try again')
                                                                    print()
                                                                    time.sleep(2)       
                                                                else:
                                                                    add_yr=datetime.date(year,month,date)
                                                                    valid=True
                                                                    ent+=1
                                                            else:
                                                                cls()
                                                                print('date not valid')
                                                                print('try again')
                                                                print()
                                                                time.sleep(2)
                                                        else:
                                                            cls()
                                                            print('date not digit')
                                                            print('try again')
                                                            print()
                                                            time.sleep(2)
                                                    else:
                                                        cls()
                                                        print('date not valid')
                                                        print('try again')
                                                        print()
                                                        time.sleep(2)
                                                else:
                                                    cls()
                                                    print('month must be between 1 and 12')
                                                    print('try again')
                                                    print()
                                                    time.sleep(2)
                                            else:
                                                cls()
                                                print('month not digit')
                                                print('try again')
                                                print()
                                                time.sleep(2)
                                        else:
                                            cls()
                                            print('month not valid')
                                            print('try again')
                                            print()
                                            time.sleep(2)

                                    else:
                                        cls()
                                        print('year not digit')
                                        print('try again')
                                        print()
                                        time.sleep(2)
                                else:
                                    cls()
                                    print('year not valid')
                                    print('try again')
                                    print()
                                    time.sleep(2)
                            grade=''
                            percentage=((phy+math+chem+pe+ip)/500)*100
                            if percentage>=90:
                                grade='A'
                            elif percentage>=80 :
                                grade='B'
                            elif percentage>=70:
                                grade='C'
                            elif percentage>=60:
                                grade='D'
                            elif percentage>=50:
                                grade='E'
                            else:
                                grade='F'
                            print(grade)
                            ent+=1
                            fee_stat=''
                            fs=0
                            while fs!=2:
                                print('''Choose An Option For The Fee Status: 
                                1) PAID
                                2) NOT-PAID''')
                                fee_stat=input('Enter a number from the menu: ')
                                fee_stat=fee_stat.strip()
                                if fee_stat.isdigit():
                                    fee_stat=int(fee_stat)
                                    if fee_stat>=1 and fee_stat<=2:
                                        if fee_stat==1:
                                            fee_stat='PAID'
                                            fs=2
                                        elif fee_stat==2:
                                            fee_stat='NOT-PAID'
                                            fs=2
                                else:
                                    cls()
                                    print('please enter a number from the menu: ')
                                    fs=0
                                    time.sleep(2)
                            ent+=1
                            if ent==13:
                                cls()
                                print('FOLLOWING DETAILS WILL BE ENTERED:-')
                                print()
                                print('1. Scholar no      ',sc)
                                print('2. student name    ',nm)
                                print('3. date of bith    ',dob)
                                print('4. class           ',cla)
                                print('5. section         ',sec)
                                print('6. phy marks       ',phy)
                                print('7. math marks      ',math)
                                print('8. chem marks      ',chem)
                                print('9. pe marks        ',pe)
                                print('10. ip marks       ',ip)
                                print('11. grade          ',grade)
                                print('12. admmission year',add_yr)
                                print('13. fee status     ',fee_stat)
                                print()
                                print()
                                print('''are you sure u want to insert into the database (y/n):-''')
                                x=input()
                                x=x.strip()

                                if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                    query="insert into student values('%s','%s','%s','%s','%s',%d,%d,%d,%d,%d,'%s','%s','%s')"%(sc,nm,dob,cla,sec,phy,math,chem,pe,ip,add_yr,grade,fee_stat)
                                    cursor.execute(query)
                                    cls()
                                    db.commit()
                                    print('record entered succesfully...')
                                    print()
                                    print()
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)

                                elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                    cls()
                                    print('Canceled..')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                                else:
                                    cls()
                                    print("didn't understand the word",x)
                                    print(' could not insert the record')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                            else:
                                cls()
                                print('something went wrong')
                                print('please try again...')
                                time.sleep(2)
                        else:
                            cls()
                            print('section must be from A to J only...')
                            print('try again...')
                            print()
                            time.sleep(2)
                    else:
                        cls()
                        print('''class must be between 1 and 12
    please try again''')
                        print()
                        time.sleep(2)
                else:
                    cls()
                    print('''class must be between 1 and 12
    please try again''')
                    print()
                    time.sleep(2)
    else:
        print('''scholar number must be a digit 
try again''')     
def update():
    
    db=c.connect(user='root',
             password='saber_blaze123',
             host='localhost',
             database='default',
             auth_plugin='mysql_native_password')
    cursor=db.cursor()
    query='select * from student'
    cursor.execute(query)
    results=cursor.fetchall()
    df=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
    
    temp=input('Enter name of student whose record you want to update: ')
    temp=temp.strip()
    temp=temp.title()
    if temp in df.values:
        query="select * from student where stu_name='%s'"%(temp)
        cls()
        print('''Select The Criteria You Want To Update:
    1. Update Class
    2. Update Section
    3. Update Physics Marks
    4. Update Math Marks
    5. Update Chemistry Marks
    6. Update PE Marks
    7. Update IP Marks
    8. Update Fee Status
        ''')
        up_no=input('Choose An Option From The Menu: ')
        up_no=up_no.strip()
        cursor.execute(query)
        results=cursor.fetchall()
        sr=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
        sr.set_index('Scho_no',inplace=True)

        if up_no.isdigit():
            up_no=int(up_no)
            if up_no>=1 and up_no<=8:
                if up_no==1:
                    cls()
                    up_clss=input('Enter new Class: ')
                    up_clss=up_clss.strip()
                    if up_clss.isdigit():
                        up_clss=int(up_clss)
                        if up_clss>=1 and up_clss<=12:
                            if len(results) > 1:
                                cls()
                                display(sr)
                                conf=input('please confirm which record to be updated by specifing its scholar no: ')
                                conf=conf.strip()    
                                while conf not in sr.index:
                                    cls()
                                    conf=input('Please enter a valid scholar no: ')
                                    conf=conf.strip()
                                
                                query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_clss not in cc.iloc[:,0:3].values:
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()
                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                        up_clss=str(up_clss)
                                        query="update student set class='%s' where stu_name='%s'and scholar_no='%s'"%(up_clss,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        cls()
                                        print('Successfully Updated...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..') 
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)                                       
                                        print(' Update Unsuccessful...')    
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                                                               
                                    
                                else:
                                    print(temp, 'already has', up_clss, 'as class')
                                    print('so the record cannot be updated...')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                                    
                            else:
                                query="select * from student where stu_name='%s'"%(temp)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_clss not in cc.iloc[:,0:3].values:
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()
                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                        up_clss=str(up_clss)
                                        query="update student set class='%s' where stu_name='%s'"%(up_clss,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('Successfully Updated...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)

                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    print(temp, 'already has', up_clss, 'as class')
                                    print('so the record cannot be updated...')
                                    time.sleep(2)
                        else:
                            print('Class Must be Between 1 And 12...')
                            time.sleep(2)
                    else:
                        print('Class Must BE An Integer Value')
                        print('Between 1 and 12')
                        time.sleep(2)
                elif up_no==2:

                    cls()
                    up_sec=input('Enter new section: ')
                    up_sec=up_sec.strip()
                    up_sec=up_sec.title()
                    sec=['A','B','C','D','E','F','G','H','I','J']
                    if up_sec in sec:
                        if len(results) > 1:
                            cls()
                            display(sr)
                            conf=input('please confirm which record to be updated by specifing its scholar no: ')
                            conf=conf.strip()    
                            while conf not in sr.index:
                                cls()
                                conf=input('Please enter a valid scholar no: ')
                                conf=conf.strip()

                            query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                            cursor.execute(query)
                            results=cursor.fetchall()
                            cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                            cc.set_index('Scho_no',inplace=True)
                            cc.iloc[:,0:4]
                            if up_sec not in cc.iloc[:,0:4].values:

                                cls()
                                print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                x=input()
                                x=x.strip()

                                if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':

                                    up_sec=str(up_sec)
                                    query="update student set section='%s' where stu_name='%s'and scholar_no='%s'"%(up_sec,temp,conf)
                                    cursor.execute(query)
                                    db.commit()
                                    cls()
                                    print('Successfully Updated...')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)

                                elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                    cls()
                                    print('Updation Process is Canceled..')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                                else:
                                    cls()
                                    print("didn't understand the word",x)
                                    print(' Update Unsuccessful...')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                            else:
                                print(temp, 'already has', up_sec, 'as section')
                                print('so the record cannot be updated...')
                                time.sleep(2)

                        else:
                            query="select * from student where stu_name='%s'"%(temp)
                            cursor.execute(query)
                            results=cursor.fetchall()
                            cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                            cc.set_index('Scho_no',inplace=True)
                           
                            
                            if up_sec not in cc.iloc[:,0:4].values:
                                cls()
                                print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                x=input()
                                x=x.strip()
                                if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                    up_sec=str(up_sec)
                                    query="update student set section='%s' where stu_name='%s'"%(up_sec,temp)
                                    cursor.execute(query)
                                    db.commit()
                                    print('Successfully Updated...')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                                elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                    cls()
                                    print('Updation Process is Canceled..')
                                    print()
                                    print()
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                                else:
                                    cls()
                                    print("didn't understand the word",x)
                                    print(' Update Unsuccessful...')
                                    print()
                                    print()
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                            else:
                                print(temp, 'already has', up_sec, 'as section')
                                print('so the record cannot be updated...')
                                print()
                                print()
                                time.sleep(2)
                    else:
                        print('INVALID SECTION...')  
                        print()
                        print()
                        time.sleep(2)

                elif up_no==3:
                    cls()
                    up_marks=input('Enter new Marks: ')
                    up_marks=up_marks.strip()
                    if up_marks.isdigit():
                        up_marks=int(up_marks)
                        if up_marks>=0 and up_marks<=100:
                            if len(results) > 1:
                                cls()
                                display(sr)
                                conf=input('please confirm which record to be updated by specifing its scholar no: ')
                                conf=conf.strip()    
                                while conf not in sr.index:
                                    cls()
                                    conf=input('Please enter a valid scholar no: ')
                                    conf=conf.strip()
                                
                                query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'Phy_marks'].values:
                                    
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()

                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':

                                        up_marks=str(up_marks)
                                        query="update student set phy_marks='%s' where stu_name='%s'and scholar_no='%s'"%(up_marks,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        cls()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'

                                        query="update student set grade='%s' where stu_name='%s'and scholar_no='%s'"%(grade,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    
                                        

                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...') 
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as phy_marks')
                                    print('so the record cannot be updated...')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                                    
                            else:
                                query="select * from student where stu_name='%s'"%(temp)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'Phy_marks'].values:
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()
                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                        up_marks=str(up_marks)
                                        query="update student set phy_marks='%s' where stu_name='%s'"%(up_marks,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s'"%(temp)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'"%(grade,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                      
                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as phy_marks')
                                    print('so the record cannot be updated...')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                        else:
                            print('Marks Must be Between 0 And 100...')
                            time.sleep(2)
                    else:
                        print('Marks Must BE An Integer Value')
                        print('Between 0 and 100')
                        time.sleep(2)

                elif up_no==4:

                    cls()
                    up_marks=input('Enter new Marks: ')
                    up_marks=up_marks.strip()
                    if up_marks.isdigit():
                        up_marks=int(up_marks)
                        if up_marks>=0 and up_marks<=100:
                            if len(results) > 1:
                                cls()
                                display(sr)
                                conf=input('please confirm which record to be updated by specifing its scholar no: ')
                                conf=conf.strip()    
                                while conf not in sr.index:
                                    cls()
                                    conf=input('Please enter a valid scholar no: ')
                                    conf=conf.strip()
                                
                                query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'Maths_marks'].values:
                                    
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()

                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':

                                        up_marks=str(up_marks)
                                        query="update student set maths_marks='%s' where stu_name='%s'and scholar_no='%s'"%(up_marks,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        cls()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'and scholar_no='%s'"%(grade,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                
                                        

                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...') 
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as math_marks')
                                    print('so the record cannot be updated...')
                                    time.sleep(2)

                            else:
                                query="select * from student where stu_name='%s'"%(temp)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'Maths_marks'].values:
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()
                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                        up_marks=str(up_marks)
                                        query="update student set Maths_marks='%s' where stu_name='%s'"%(up_marks,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s'"%(temp)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'"%(grade,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                      
                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as math_marks')
                                    print('so the record cannot be updated...')
                                    time.sleep(2)
                        else:
                            print('Marks Must be Between 0 And 100...')
                            time.sleep(2)
                    else:
                        print('Marks Must BE An Integer Value')
                        print('Between 0 and 100') 
                        time.sleep(2)
                
                elif up_no==5:

                    cls()
                    up_marks=input('Enter new Marks: ')
                    up_marks=up_marks.strip()
                    if up_marks.isdigit():
                        up_marks=int(up_marks)
                        if up_marks>=0 and up_marks<=100:
                            if len(results) > 1:
                                cls()
                                display(sr)
                                conf=input('please confirm which record to be updated by specifing its scholar no: ')
                                conf=conf.strip()    
                                while conf not in sr.index:
                                    cls()
                                    conf=input('Please enter a valid scholar no: ')
                                    conf=conf.strip()
                                
                                query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'Chem_marks'].values:
                                    
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()

                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':

                                        up_marks=str(up_marks)
                                        query="update student set Chem_marks='%s' where stu_name='%s'and scholar_no='%s'"%(up_marks,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        cls()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'and scholar_no='%s'"%(grade,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                       
                                        

                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as chem_marks')
                                    print('so the record cannot be updated...')
                                    time.sleep(2)

                            else:
                                query="select * from student where stu_name='%s'"%(temp)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'Chem_marks'].values:
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()
                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                        up_marks=str(up_marks)
                                        query="update student set Chem_marks='%s' where stu_name='%s'"%(up_marks,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s'"%(temp)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'"%(grade,temp)
                                        cursor.execute(query)
                                        db.commit()
                                  
                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as chem_marks')
                                    print('so the record cannot be updated...')
                                    time.sleep(2)
                        else:
                            print('Marks Must be Between 0 And 100...')
                            time.sleep(2)
                            
                    else:
                        print('Marks Must BE An Integer Value')
                        print('Between 0 and 100')
                        time.sleep(2)
                        
                elif up_no==6:

                    cls()
                    up_marks=input('Enter new Marks: ')
                    up_marks=up_marks.strip()
                    if up_marks.isdigit():
                        up_marks=int(up_marks)
                        if up_marks>=0 and up_marks<=100:
                            if len(results) > 1:
                                cls()
                                display(sr)
                                conf=input('please confirm which record to be updated by specifing its scholar no: ')
                                conf=conf.strip()    
                                while conf not in sr.index:
                                    cls()
                                    conf=input('Please enter a valid scholar no: ')
                                    conf=conf.strip()
                                
                                query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'PE_marks'].values:
                                    
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()

                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':

                                        up_marks=str(up_marks)
                                        query="update student set PE_marks='%s' where stu_name='%s'and scholar_no='%s'"%(up_marks,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        cls()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'and scholar_no='%s'"%(grade,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                     
                                        

                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')      
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as PE_marks')
                                    print('so the record cannot be updated...')   
                                    time.sleep(2)

                            else:
                                query="select * from student where stu_name='%s'"%(temp)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'PE_marks'].values:
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()
                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                        up_marks=str(up_marks)
                                        query="update student set PE_marks='%s' where stu_name='%s'"%(up_marks,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s'"%(temp)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'"%(grade,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                      
                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as PE_marks')
                                    print('so the record cannot be updated...')
                                    print('''redirecting to home screen...
please wait...''')
                                    time.sleep(2)
                        else:
                            print('Marks Must be Between 0 And 100...')
                            time.sleep(2)
                    else:
                        print('Marks Must BE An Integer Value')
                        print('Between 0 and 100')
                        time.sleep(2)
                        
                elif up_no==7:

                    cls()
                    up_marks=input('Enter new Marks: ')
                    up_marks=up_marks.strip()
                    if up_marks.isdigit():
                        up_marks=int(up_marks)
                        if up_marks>=0 and up_marks<=100:
                            if len(results) > 1:
                                cls()
                                display(sr)
                                conf=input('please confirm which record to be updated by specifing its scholar no: ')
                                conf=conf.strip()    
                                while conf not in sr.index:
                                    cls()
                                    conf=input('Please enter a valid scholar no: ')
                                    conf=conf.strip()
                                
                                query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'IP_marks'].values:
                                    
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()

                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':

                                        up_marks=str(up_marks)
                                        query="update student set IP_marks='%s' where stu_name='%s'and scholar_no='%s'"%(up_marks,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        cls()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'and scholar_no='%s'"%(grade,temp,conf)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                      

                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')     
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as IP_marks')
                                    print('so the record cannot be updated...')  
                                    time.sleep(2)

                            else:
                                query="select * from student where stu_name='%s'"%(temp)
                                cursor.execute(query)
                                results=cursor.fetchall()
                                cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                cc.set_index('Scho_no',inplace=True)
                                if up_marks not in cc.loc[:,'IP_marks'].values:
                                    cls()
                                    print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                    x=input()
                                    x=x.strip()
                                    if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                        up_marks=str(up_marks)
                                        query="update student set IP_marks='%s' where stu_name='%s'"%(up_marks,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('Successfully Updated...')
                                        query="select * from student where stu_name='%s'"%(temp)
                                        cursor.execute(query)
                                        results=cursor.fetchall()
                                        cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                        cc.set_index('Scho_no',inplace=True)
                                        s=0
                                        for i in cc.loc[:,['Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks',]].values:
                                            print()
                                        for x in i:
                                            s=s+x
                                         

                                        grade=''
                                        percentage=(s/500)*100
                                        if percentage>=90:
                                            grade='A'
                                        elif percentage>=80 :
                                            grade='B'
                                        elif percentage>=70:
                                            grade='C'
                                        elif percentage>=60:
                                            grade='D'
                                        elif percentage>=50:
                                            grade='E'
                                        else:
                                            grade='F'
                                        query="update student set grade='%s' where stu_name='%s'"%(grade,temp)
                                        cursor.execute(query)
                                        db.commit()
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                      
                                    elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                        cls()
                                        print('Updation Process is Canceled..')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                    else:
                                        cls()
                                        print("didn't understand the word",x)
                                        print(' Update Unsuccessful...')
                                        print('''redirecting to home screen...
please wait...''')
                                        time.sleep(2)
                                else:
                                    cls()
                                    print(temp, 'already has', up_marks, 'as IP_marks')
                                    print('so the record cannot be updated...')
                                    time.sleep(2)
                        else:
                            print('Marks Must be Between 0 And 100...')
                            time.sleep(2)
                    else:
                        print('Marks Must BE An Integer Value')
                        print('Between 0 and 100')
                        time.sleep(2)
                        
                elif up_no==8:
                    cls()
                    print(''' choose the updated fee status
                    1. PAID
                    2. NOT PAID''') 
                    up_fee=input()
                    up_fee=up_fee.strip()
                    if up_fee.isdigit:
                        up_fee=int(up_fee)
                        if up_fee>=1 and up_fee<=2:
                            if up_fee==1:
                                y='PAID'
                                if len(results) > 1:
                                    cls()
                                    display(sr)
                                    conf=input('please confirm which record to be updated by specifing its scholar no: ')
                                    conf=conf.strip()    
                                    while conf not in sr.index:
                                        cls()
                                        conf=input('Please enter a valid scholar no: ')
                                        conf=conf.strip()
                                
                                    query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                    cursor.execute(query)
                                    results=cursor.fetchall()
                                    cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                    cc.set_index('Scho_no',inplace=True)
                                    if y not in cc.values:
                                        cls()
                                        print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                        x=input()
                                        x=x.strip()
                                        if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                            query="update student set fee_status='%s' where stu_name='%s'and scholar_no='%s'"%(y,temp,conf)
                                            cursor.execute(query)
                                            db.commit()
                                            cls()
                                            print('Successfully Updated...')
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                        elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                            cls()
                                            print('Updation Process is Canceled..') 
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                        else:
                                            cls()
                                            print("didn't understand the word",x)                                       
                                            print(' Update Unsuccessful...') 
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                            
                                    else:
                                        cls()
                                        print(temp,'already has',y,'as its PAID_STATUS')
                                        print('so can not update the record')
                                        time.sleep(2)
                                    
                               
                                else:
                                    cls()
                                    query="select * from student where stu_name='%s'"%(temp)
                                    cursor.execute(query)
                                    results=cursor.fetchall()
                                    cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                    cc.set_index('Scho_no',inplace=True)
                                    if y not in cc.values:
                                        cls()
                                        print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                        x=input()
                                        x=x.strip()
                                        if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                            query="update student set fee_status='%s' where stu_name='%s'"%(y,temp)
                                            cursor.execute(query)
                                            db.commit()
                                            cls()
                                            print('Successfully Updated...')
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                        elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                            cls()
                                            print('Updation Process is Canceled..')  
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                        else:
                                            cls()
                                            print("didn't understand the word",x)                                       
                                            print(' Update Unsuccessful...')
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                    else:
                                        cls()
                                        print(temp,'already has',y,'as its PAID_STATUS')
                                        print('so can not update the record')
                                        time.sleep(2)
                            if up_fee==2:
                                y='NOT PAID'
                                if len(results) > 1:
                                    cls()
                                    display(sr)
                                    conf=input('please confirm which record to be updated by specifing its scholar no: ')
                                    conf=conf.strip()    
                                    while conf not in sr.index:
                                        cls()
                                        conf=input('Please enter a valid scholar no: ')
                                        conf=conf.strip()
                                
                                    query="select * from student where stu_name='%s' and scholar_no='%s'"%(temp,conf)
                                    cursor.execute(query)
                                    results=cursor.fetchall()
                                    cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                    cc.set_index('Scho_no',inplace=True)
                                    if y not in cc.values:
                                        cls()
                                        print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                        x=input()
                                        x=x.strip()
                                        if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                            query="update student set fee_status='%s' where stu_name='%s'and scholar_no='%s'"%(y,temp,conf)
                                            cursor.execute(query)
                                            db.commit()
                                            cls()
                                            print('Successfully Updated...')
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                        elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                            cls()
                                            print('Updation Process is Canceled..')    
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                        else:
                                            cls()
                                            print("didn't understand the word",x)                                       
                                            print(' Update Unsuccessful...')       
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                    else:
                                        cls()
                                        print(temp,'already has',y,'as its PAID_STATUS')
                                        print('so can not update the record')
                                        time.sleep(2)
                                    
                               
                                else:
                                    cls()
                                    query="select * from student where stu_name='%s'"%(temp)
                                    cursor.execute(query)
                                    results=cursor.fetchall()
                                    cc=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                                    cc.set_index('Scho_no',inplace=True)
                                    if y not in cc.values:
                                        cls()
                                        print('Are you sure you want to proceed with updating record of',temp,'(yes/no)')
                                        x=input()
                                        x=x.strip()
                                        if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                                            query="update student set fee_status='%s' where stu_name='%s'"%(y,temp)
                                            cursor.execute(query)
                                            db.commit()
                                            cls()
                                            print('Successfully Updated...')
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                        elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                                            cls()
                                            print('Updation Process is Canceled..')
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                        else:
                                            cls()
                                            print("didn't understand the word",x)                                       
                                            print(' Update Unsuccessful...')
                                            print('''redirecting to home screen...
please wait...''')
                                            time.sleep(2)
                                    else:
                                        cls()
                                        print(temp,'already has',y,'as its PAID_STATUS')
                                        print('so can not update the record')
                                        time.sleep(2)


            else:
                cls()
                print('option not in menu: ')
                print('please wait...')
                time.sleep(2)
        else:
            cls()
            print('not in menu: ')
            print('please wait...')
            print()
            time.sleep(2)
    else:
        cls()
        print('NO RECORD AVAILABLE FOR',temp)
        print('COULD NOT PROCCED')
        print('please wait...')
        print()
        time.sleep(2)
        
def delete():
    db=c.connect(user='root',
             password='saber_blaze123',
             host='localhost',
             database='default',
             auth_plugin='mysql_native_password')
    cursor=db.cursor()
    query='select * from student'
    cursor.execute(query)
    results=cursor.fetchall()
    df=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
    
    temp=input('Enter name of student whose record you want to delete: ')
    temp=temp.strip()
    temp=temp.title()
    if temp in df.values:
        query="select * from student where stu_name='%s'"%(temp)
        cls()
        cursor.execute(query)
        results=cursor.fetchall()
        sr=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
        sr.set_index('Scho_no',inplace=True)
        if len(results)>1:
            cls()
            display(sr)
            conf=input('please confirm which record to be updated by specifing its scholar no: ')
            conf=conf.strip()    
            while conf not in sr.index:
                cls()
                conf=input('Please enter a valid scholar no: ')
                conf=conf.strip()
            print('Are you sure you want to proceed with deleting record of',temp,' and scholar no ',conf,'(yes/no)')
            x=input()
            x=x.strip()
            if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                query="delete from student where stu_name='%s'and scholar_no='%s'"%(temp,conf)
                cursor.execute(query)
                db.commit()
                cls()
                print('Successfully Updated...')
                print('''redirecting to home screen...
please wait...''')
                time.sleep(2)
            elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                cls()
                print('Updation Process is Canceled..') 
                print('''redirecting to home screen...
please wait...''')
                time.sleep(2)
            else:
                cls()
                print("didn't understand the word",x)                                       
                print(' Update Unsuccessful...')  
                print('''redirecting to home screen...
please wait...''')
                time.sleep(2)
        else:
            cls()
            print('Are you sure you want to proceed with deleting record of',temp,'(yes/no)')
            x=input()
            x=x.strip()
            if x == 'yes' or x=='Yes' or x=='YES' or x=='y' or x =='Y':
                query="delete from student where stu_name='%s'"%(temp)
                cursor.execute(query)
                db.commit()
                cls()
                print('Successfully Updated...')
                print('''redirecting to home screen...
please wait...''')
                time.sleep(2)
            elif x == 'no' or x=='No' or x=='NO' or x=='n' or x =='N':
                cls()
                print('Updation Process is Canceled..')  
                print('''redirecting to home screen...
please wait...''')
                time.sleep(2)
            else:
                cls()
                print("didn't understand the word",x)                                       
                print(' Update Unsuccessful...')
                print('''redirecting to home screen...
please wait...''')
                time.sleep(2)
    else:
        cls()
        print('No record found for ',temp)
        print()
        time.sleep(2)
        
def select():
    cls()
    db=c.connect(user='root',
             password='saber_blaze123',
             host='localhost',
             database='default',
             auth_plugin='mysql_native_password')
    cursor=db.cursor()
    query='select * from student'
    cursor.execute(query)
    results=cursor.fetchall()
    df=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
    df.set_index('Scho_no',inplace=True)
    print('''Select The Criteria By Which You Want To Search:
    1. search by scholar no.
    2. search by name
    3. search by class
    4. search by fee_status
        ''')
    sr_no=input('Choose An Option From The Menu: ')
    sr_no=sr_no.strip()
    cls()
    if sr_no.isdigit():
        sr_no=int(sr_no)
        if sr_no>=1 and sr_no<=4:
            if sr_no==1:
                cls()
                conf=input('please enter scholar no. you want to search:- ')
                conf=conf.strip()    
                if conf not in df.index:
                    cls()
                    print('no record available for scholar no -',conf)              
                else:
                    cls()
                    query="select * from student where scholar_no='%s'"%(conf)
                    cursor.execute(query)
                    results=cursor.fetchall()
                    sr=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                    sr.set_index('Scho_no',inplace=True)
                    dis=0
                    while dis==0:
                        display(sr)
                        print()
                        dis=input('enter any value to go back to main screen:')
                        if len(dis)>0:
                            dis=1
                            cls()
                            print()
                        else:
                            cls()
                            dis=0
            elif sr_no==2:
                cls()
                conf=input('please enter name you want to search:- ')
                conf=conf.strip()  
                conf=conf.title()
                if conf not in df.values:
                    cls()
                    print('no record available for',conf)              
                else:
                    cls()
                    query="select * from student where stu_name='%s'"%(conf)
                    cursor.execute(query)
                    results=cursor.fetchall()
                    sr=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                    sr.set_index('Scho_no',inplace=True)
                    cls()
                    dis=0
                    while dis==0:
                        display(sr)
                        print()
                        dis=input('enter any value to go back to main screen:')
                        if len(dis)>0:
                            dis=1
                            cls()
                            print()
                        else:
                            cls()
                            dis=0
            elif sr_no==3:
                conf=input('please enter class you want to search:- ')
                conf=conf.strip()
                if conf.isdigit():
                    conf=int(conf)
                    cls()
                    if conf >=1 and conf <=12:
                        if conf not in df.values:
                            cls()
                            print('no record available for',conf)              
                        else:
                            cls()
                            conf=str(conf)
                            query="select * from student where class='%s'"%(conf)
                            cursor.execute(query)
                            results=cursor.fetchall()
                            sr=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                            sr.set_index('Scho_no',inplace=True)
                            cls()
                            dis=0
                            while dis==0:
                                display(sr)
                                print()
                                dis=input('enter any value to go back to main screen:')
                                if len(dis)>0:
                                    dis=1
                                    cls()
                                    print()
                                else:
                                    cls()
                                    dis=0
                    else:
                        cls()
                        print('class must be between 1 and 12')
                else:
                    cls()
                    print('class must be between 1 and 12')
                    
            elif sr_no==4:
                cls()
                print('''select which option u want to seach with:
                1. PAID
                2.NOT PAID''')
                conf=input()
                conf=conf.strip()  
                if conf.isdigit():
                    conf=int(conf)
                    cls()
                    if conf >=1 and conf <=2:
                        if conf == 1:
                            cls()
                            x='PAID' 
                            query="select * from student where FEE_Status='%s'"%(x)
                            cursor.execute(query)
                            results=cursor.fetchall()
                            sr=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                            sr.set_index('Scho_no',inplace=True)
                            cls()
                            dis=0
                            while dis==0:
                                display(sr)
                                print()
                                dis=input('enter any value to go back to main screen:')
                                if len(dis)>0:
                                    dis=1
                                    cls()
                                    print()
                                else:
                                    cls()
                                    dis=0
                        else:
                            cls()
                            x='NOT-PAID' 
                            query="select * from student where FEE_Status='%s'"%(x)
                            cursor.execute(query)
                            results=cursor.fetchall()
                            sr=pd.DataFrame(results,columns=['Scho_no','Student Name','DoB','Class','Section','Phy_marks','Maths_marks','Chem_marks','PE_marks','IP_marks','Ad_yr','Grades','FEE_Status'])
                            sr.set_index('Scho_no',inplace=True)
                            cls()
                            dis=0
                            while dis==0:
                                display(sr)
                                print()
                                dis=input('enter any value to go back to main screen:')
                                if len(dis)>0:
                                    dis=1
                                    cls()
                                    print()
                                else:
                                    cls()
                                    dis=0
                    else:
                        cls()
                        print('choose an option from menu')
                else:
                    cls()
                    print('choose an opyion from menu')
#program loop
acc=1
while acc !=0:
    print('''1. log_in
2. sign_up
3. view log_in history
4. exit programe''')
    ch=input('Enter a choice from the menu')
    ch=ch.strip()
    cls()
    if ch.isdigit():
        ch=int(ch)
        if ch>=1 and ch<=4:
            if ch==1:
                db=c.connect(user='root',
                             password='saber_blaze123',
                             host='localhost',
                             database='default',
                             auth_plugin='mysql_native_password')
                cursor=db.cursor()
                query='select * from accounts'
                cursor.execute(query)
                results=cursor.fetchall()
                ACC=pd.DataFrame(results,columns=['id','password'])
                ACC.set_index('id', inplace=True)
                Id=input('enter your account id')
                if Id.isdigit():
                    Id=int(Id)
                    pswd=input('enter your password')
                    query="select * from accounts where id=%d and pswd='%s'"%(Id,pswd)
                    cursor.execute(query)
                    results=cursor.fetchall()    
                    if len(results)==1:
                        cls()
                        print('loged in successfully... ')
                        print('welcome user-',Id)
                        login_DT=datetime.datetime.today()
                        login_time = login_DT.time()
                        date = login_DT.date()
                        print()
                        print()
                        print('''redirecting to home screen...
please wait...''')
                        time.sleep(2)
                        ch=1
                        while ch!=0:
                            cls()
                            print('''1.Display record
2.Insert new record
3.Update record
4.Delete record
5.Search with criteria
6.Logout''')
                            ch=input('Enter a number from the menu: ')
                            ch=ch.strip()
                            if ch.isdigit():
                                ch=int(ch)
                                if ch>=1 and ch<=6:
                                    if ch==1:
                                        cls()
                                        disp()
                                    elif ch==2:
                                        cls()
                                        new()
                                        time.sleep(3)
                                    elif ch==3:
                                        cls()
                                        update()
                                    elif ch==4:
                                        cls()
                                        delete()
                                    elif ch==5:
                                        cls()
                                        select() 
                                    else:
                                        cls()
                                        ch=0
                                        logout_DT=datetime.datetime.today()
                                        logout_time = logout_DT.time()
                                        query="insert into log_history values(%d,'%s','%s','%s')" % (Id,login_time,logout_time,date)
                                        cursor.execute(query)
                                        db.commit()
                                        
                            else:
                                cls()
                                print('please enter a number from the menu: ')
                    else:
                        cls()
                        print('''Sorry your id and password did not match...
pls try again''')
                        time.sleep(2)
                else:
                    cls()
                    print('''THERE ISE NO SUCH ACCOUNT ID...
pls try again''')
                    time.sleep(2)
                
            elif ch==2:
                db=c.connect(user='root',
                             password='saber_blaze123',
                             host='localhost',
                             database='default',
                             auth_plugin='mysql_native_password')
                cursor=db.cursor()
                query='select * from accounts'
                cursor.execute(query)
                results=cursor.fetchall()
                ACC=pd.DataFrame(results,columns=['id','password'])
                ACC.set_index('id', inplace=True)
                new=1
                while new!=0:
                    cls()
                    ID=input('''enter new id no. ''')
                    if ID.isdigit():
                        ID=int(ID)
                        if ID not in ACC.index:
                            psd=1
                            while psd!=0:
                                PSWD=input('''enter password
tip- password must contain both 
     number and letters''')
                                if PSWD.isdigit():
                                    cls()
                                    print('''password must contain letters too
                                    its weak right now...
                                    TRY AGAIN...''')
                                    time.sleep(2)
                                elif PSWD.isalpha():
                                    cls()
                                    print('''password must contain numbers too
                                    its weak right now...
                                    TRY AGAIN...''')
                                    time.sleep(2)
                                else: 
                                    cls()
                                    print('account has been created successfully...')
                                    
                                    query="insert into accounts values(%d,'%s')"%(ID,PSWD)
                                    cursor.execute(query)
                                    db.commit()
                                    
                                    psd=0
                                    time.sleep(2)
                            new=0
                    
                        else:
                            cls()
                            print('account no. already exists')
                            print('try again...')
                            time.sleep(2)
                    else:
                        cls()
                        print('id no. must be digit')
                        time.sleep(2)
                
            elif ch==3:
                db=c.connect(user='root',
                             password='saber_blaze123',
                             host='localhost',
                             database='default',
                             auth_plugin='mysql_native_password')
                cursor=db.cursor()
                query='select * from log_history'
                cursor.execute(query)
                results=cursor.fetchall()
                LOG=pd.DataFrame(results,columns=['id','log_in_time','log_out_time','Date_log'])
                LOG.set_index('id', inplace=True)
                dis=0
                while dis==0:
                    display(LOG)
                    print()
                    dis=input('enter any value to go back to main screen:')
                    if len(dis)>0:
                        dis=1
                        cls()
                        print()
                    else:
                        cls()
                        dis=0
                
               
            else:
                acc=0
                print('''Thank you for using the programe
                      and give us full for practicals 😆''')
                
              
    else:
        cls()
        print('please enter a number from the menu: ')
# Out:
# Thank you for using the programe
#                       and give us full for practicals 😆
